# %%
import numpy as np

# %%
d = {'key1': 'value1', 'key2': 'value2'}

print(d)
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
d['key1']
# Out:
# 'value1'

# %%
d.items()
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2')])

# %%
d.values()
# Out:
# dict_values(['value1', 'value2'])

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

d2 = ConfigBox({'key1': 'value1', 'key2': 'value2'})

d2.key1
# Out:
# 'value1'

# %%
def get_number(x: int, y: int) -> int:
    return x*y

# %%
get_number(x = 2, y = 3)
# Out:
# 6

# %%
get_number(x = 2, y = 'a')
# Out:
# 'aa'

# %%
from typeguard import typechecked

@typechecked
def get_number(x: int, y: int) -> int:
    return x*y



get_number(x = 2, y = 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from typeguard import typechecked
#       2
# ----> 3 @typechecked
#       4 def get_number(x: int, y: int) -> int:
#       5     return x*y
#       6
#
# File c:\Users\VENKATESH\ML_project\venv\Lib\site-packages\typeguard\_decorators.py:230, in typechecked(target, forward_ref_policy, typecheck_fail_callback, collection_check_strategy, debug_instrumentation)
#     227     wrapper_class = target.__class__
#     228     target = target.__func__  # type: ignore[assignment]
# --> 230 retval = instrument(target)
#     231 if isinstance(retval, str):
#     232     warn(
#     233         f"{retval} -- not typechecking {function_name(target)}",
#     234         InstrumentationWarning,
#     235         stacklevel=get_stacklevel(),
#     236     )
#
# File c:\Users\VENKATESH\ML_project\venv\Lib\site-packages\typeguard\_decorators.py:70, in instrument(f)
#      64     return (
#      65         "@typechecked only supports instrumenting functions wrapped with "
#      66         "@classmethod, @staticmethod or @property"
#      67     )
#      69 target_path = [item for item in f.__qualname__.split(".") if item != "<locals>"]
# ---> 70 module_source = inspect.getsource(sys.modules[f.__module__])
#      71 module_ast = ast.parse(module_source)
#      72 instrumentor = TypeguardTransformer(target_path, f.__code__.co_firstlineno)
#
# File ~\miniconda3\Lib\inspect.py:1263, in getsource(object)
#    1257 def getsource(object):
#    1258     """Return the text of the source code for an object.
#    1259
#    1260     The argument may be a module, class, method, function, traceback, frame,
#    1261     or code object.  The source code is returned as a single string.  An
#    1262     OSError is raised if the source code cannot be retrieved."""
# -> 1263     lines, lnum = getsourcelines(object)
#    1264     return ''.join(lines)
#
# File ~\miniconda3\Lib\inspect.py:1245, in getsourcelines(object)
#    1237 """Return a list of source lines and starting line number for an object.
#    1238
#    1239 The argument may be a module, class, method, function, traceback, frame,
#    (...)   1242 original source file the first line of code was found.  An OSError is
#    1243 raised if the source code cannot be retrieved."""
#    1244 object = unwrap(object)
# -> 1245 lines, lnum = findsource(object)
#    1247 if istraceback(object):
#    1248     object = object.tb_frame
#
# File ~\miniconda3\Lib\inspect.py:1060, in findsource(object)
#    1052 def findsource(object):
#    1053     """Return the entire source file and starting line number for an object.
#    1054
#    1055     The argument may be a module, class, method, function, traceback, frame,
#    1056     or code object.  The source code is returned as a list of all the lines
#    1057     in the file and the line number indexes a line in that list.  An OSError
#    1058     is raised if the source code cannot be retrieved."""
# -> 1060     file = getsourcefile(object)
#    1061     if file:
#    1062         # Invalidate cache if needed.
#    1063         linecache.checkcache(file)
#
# File ~\miniconda3\Lib\inspect.py:963, in getsourcefile(object)
#     959 def getsourcefile(object):
#     960     """Return the filename that can be used to locate an object's source.
#     961     Return None if no way can be identified to get the source.
#     962     """
# --> 963     filename = getfile(object)
#     964     all_bytecode_suffixes = importlib.machinery.DEBUG_BYTECODE_SUFFIXES[:]
#     965     all_bytecode_suffixes += importlib.machinery.OPTIMIZED_BYTECODE_SUFFIXES[:]
#
# File ~\miniconda3\Lib\inspect.py:924, in getfile(object)
#     922     if getattr(object, '__file__', None):
#     923         return object.__file__
# --> 924     raise TypeError('{!r} is a built-in module'.format(object))
#     925 if isclass(object):
#     926     if hasattr(object, '__module__'):
#
# TypeError: <module '__main__'> is a built-in module
